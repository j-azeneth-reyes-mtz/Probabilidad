# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad3/Practica4_u3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística.
# ##Unidad 3.
# ##Practica 4.
# ##Maestro: José Gabriel Rodriguez Rivas.
# ##Alumna: Judith Azeneth Reyes Martínez.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [5, 6, 7, 8, 9 ,10] #Valores posibles de la variable aleatoria
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10] #Probabilidades correspondientes

#calcular funcion acumulada
F = np.cumsum(p)

#Mostrar resultados
for xi, fi in zip(x, F):
  print(f"F({xi}) = {fi:.2f}")

#Graficar
plt.step(x, F, where='post')
plt.title("Funcion de Distribucion Acumulada(FDA)")
plt.xlabel("Calificacion")
plt.ylabel("Probabilidad Acumulada")
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(5) = 0.05
# F(6) = 0.15
# F(7) = 0.35
# F(8) = 0.65
# F(9) = 0.90
# F(10) = 1.00
