# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad3/Practica3_u3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadídtica.
# ##Unidad 3.
# ##Practica 3.
# ##Maestro: José Gabriel Rodriguez Rivas.
# ##Alumna: Judith Azeneth Reyes Martínez.

# %%
import math

# %%
x = [5, 6, 7, 8, 9, 10]
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

#Calcular E(x)
esperanza = 0
for i in range (len(x)):
  esperanza += (x[i]) * p[i]


#Calcular E(X al cuadrado)
esperanza_cuadrado = 0
for i in range(len(x)):
  esperanza_cuadrado += (x[i] ** 2) * p[i]


#Calcular varianza y desviacion estandar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

#Mostrar resultados
print(f"E(X) = {esperanza:.2f}")
print(f"E(X al cuadrado) = {esperanza_cuadrado:.2f}")
print(f"Varianza = {varianza:.2f}")
print(f"Desviacion estandar = {desviacion:.2f}")
# Out:
# E(X) = 7.90
# E(X al cuadrado) = 64.10
# Varianza = 1.69
# Desviacion estandar = 1.30
