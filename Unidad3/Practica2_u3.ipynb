# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad3/Practica2_u3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística.
# ##Unidad 3.
# ##Práctica 2.
# ##Maestro: José Gabriel Rodriguez Rivas.
# ##Alumna: Judith Azeneth Reyes Martínez.

# %%
x = [5, 6, 7, 8, 9, 10] #Valores posibles de la variable aleatoria
p = [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]  #Probabilidades correspondientes

#Inicializar una variable para acumular la suma
valor_esperado = 0

#Recorrer los valores y sus probabilidades
for i in range(len(x)):
  xi = x[i]  #valor de la variable aleatoria
  pi = p[i]  #probabilidad de ese valor
  producto = xi * pi   #multiplicar de ese valor por su probabilidad
  valor_esperado += producto   #sumar acumulador
  #mostrar cada paso
  print(f"x = {xi}, p = {pi}, x*p = {producto:.2f}")


#mostar resultado final
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 5, p = 0.05, x*p = 0.25
# x = 6, p = 0.1, x*p = 0.60
# x = 7, p = 0.2, x*p = 1.40
# x = 8, p = 0.3, x*p = 2.40
# x = 9, p = 0.25, x*p = 2.25
# x = 10, p = 0.1, x*p = 1.00
#
# Valor esperado (Esperanza): 7.90
