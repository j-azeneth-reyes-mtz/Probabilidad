# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad3/Ejercicio3_unidad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística.
# ##Unidad 3.
# ##Maestro: José Gabriel Rodriguez Rivas.
# ##Alumna: Judith Azeneth Reyes Martínez.
# ###Ejercicio 3.

# %%
import matplotlib.pyplot as plt
import math

# %%
# Valores de la variable aleatoria
x = [0, 1, 2, 3, 4, 5]
p = [0.05, 0.10, 0.25, 0.30, 0.20, 0.10]

# %%
#Distribucion de probabilidad en X
# Recorrer los valores y sus probabilidades para calcular el valor esperado paso a paso
valor_esperado = 0 # Initialize valor_esperado
for i in range(len(x)):
  xi = x[i] # Valor de la variable aleatoria
  pi = p[i] # Probabilidad de ese valor
  producto = xi * pi # Multiplicar valor por su probabilidad
  valor_esperado += producto
  # Mostrar cada paso
  print(f"x = {xi}, p = {pi}, xi*pi = {producto:.2f}")

# Mostrar resultado final
print(f"\nValor esperado (Esperanza): {valor_esperado:.2f}")
# Out:
# x = 0, p = 0.05, xi*pi = 0.00
# x = 1, p = 0.1, xi*pi = 0.10
# x = 2, p = 0.25, xi*pi = 0.50
# x = 3, p = 0.3, xi*pi = 0.90
# x = 4, p = 0.2, xi*pi = 0.80
# x = 5, p = 0.1, xi*pi = 0.50
#
# Valor esperado (Esperanza): 2.80

# %%
# Verificar suma = 1
print("Suma de probabilidades:", sum(p))
# Out:
# Suma de probabilidades: 1.0

# %%
#Calcular E(x)
esperanza=0
for i in range(len(x)):
  esperanza += x[i] * p[i]

#Calcular E(X elevado al cuadrado)
esperanza_cuadrado = 0
for i in range(len(x)):
   esperanza_cuadrado += (x[i] ** 2) * p[i]

# %%
import math
#Calcular varianza y desviacion estandar (moved outside the loop)
varianza = esperanza_cuadrado - (esperanza ** 2)
desviacion = math.sqrt(varianza)
#Mostrar resultados (moved outside the loop)
print(f"E(X)= {esperanza:.2F}")

print(f"Varianza= {varianza:.2F}")
print(f"Desviacion estandar= {desviacion:.2F}")
# Out:
# E(X)= 2.80
# Varianza= 1.66
# Desviacion estandar= 1.29

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
#Calcular funcion acumulada
F=np.cumsum(p)
#Mostrar resutados
for xi, fi, in zip(x, F):
  print(f"F({xi}) = {fi:.2f}")

#Graficar
plt.step(x, F, where='post')
plt.title('Funcion de distribucion acumulada')
plt.xlabel('Calificacion')
plt.ylabel('Probabilidad acumulada')
plt.grid(True)
plt.ylim(0, 1.05)
plt.show()
# Out:
# F(0) = 0.05
# F(1) = 0.15
# F(2) = 0.40
# F(3) = 0.70
# F(4) = 0.90
# F(5) = 1.00

# %% [markdown]
# ¿Cuantas unidades se esperan vender por semana? Como el valor esperado es 2.80,por lo tanto se esperan vender 2.80 unidades por semana.
#
#
#
# ¿La demanda es estable o muy variable? La demanda presenta una variabilidad moderada ya que la desviación estándar de 1.29 es casi la mitad del valor esperado (2.80).
