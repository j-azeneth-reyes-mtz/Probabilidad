# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad1/Practica5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Unidad 1.
# ##Practica 5.
# ##Maestro: José Gabriel Rodríguez Rivas.
# ##Alumno: Judith Azeneth Reyes Martínez.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot

# %%
import zipfile
import os

# Define the path to the zip file
zip_file_path = '/content/20-06-30-COVID19MEXICO - codificado.zip'

# Define the directory to extract to
extract_dir = '/content/'

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# Now, read the extracted CSV file. Assuming the CSV file inside has a similar name.
# Let's list files in content to confirm the name of the extracted CSV if not sure.
# For now, I'll assume it extracts to '20-06-30-COVID19MEXICO - codificado.csv'
covid = pd.read_csv(os.path.join(extract_dir, '20-06-30-COVID19MEXICO - codificado.csv'), encoding = "latin1")

# %%
covid.info()

# %%
covid.head()
