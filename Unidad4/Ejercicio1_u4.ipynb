# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad4/Ejercicio1_u4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística.
# ##Unidad 4.
# ##Práctica 1.
# ##Maestro: José Gabriel Rodriguez Rivas.
# ##Alumna: Judith Azeneth Reyes Martínez.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
#Generar datos para la distribucion normal

media = 70 #Media
desv_std = 4 #Desviacion estámdar
num_datos = 500

#generamos los adtos de manera aleatoria y lon en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50] #Mostrar los primeros 50
# Out:
# array([68.29447403, 68.59664957, 61.1080516 , 68.43935343, 75.10222539,
#        69.03519817, 76.89277168, 74.49216919, 63.68537027, 67.60390524,
#        63.28907916, 72.34283347, 72.72810799, 75.55893136, 68.59944279,
#        71.91391216, 65.01191641, 76.7221053 , 71.85663083, 75.04696763,
#        76.11342146, 68.43888591, 73.39795552, 69.6790921 , 71.48711049,
#        76.06927064, 67.82713294, 66.60043864, 73.55618179, 69.0146317 ,
#        75.80650449, 72.67337092, 69.05745253, 71.63481365, 71.77861333,
#        63.663914  , 70.46686429, 65.83035813, 68.45912424, 78.50980222,
#        69.05591552, 67.38710299, 77.97279369, 66.15779828, 74.62564624,
#        68.10532635, 76.69106912, 76.09952914, 75.167814  , 71.56692781])

# %%
# Crear un rango de valores para crear una densidad
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)

#Calcular la PDF de la distribucoion normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-((x - media)** 2) / (2 * desv_std ** 2))

#Para no imprimir toda la lista de valores (500), desplegamos los primeros 50
print("Imprimir los primeros 50 Valores x", x[0:50], ", y los primeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 Valores x [54.         54.03203203 54.06406406 54.0960961  54.12812813 54.16016016
#  54.19219219 54.22422422 54.25625626 54.28828829 54.32032032 54.35235235
#  54.38438438 54.41641642 54.44844845 54.48048048 54.51251251 54.54454454
#  54.57657658 54.60860861 54.64064064 54.67267267 54.7047047  54.73673674
#  54.76876877 54.8008008  54.83283283 54.86486486 54.8968969  54.92892893
#  54.96096096 54.99299299 55.02502503 55.05705706 55.08908909 55.12112112
#  55.15315315 55.18518519 55.21721722 55.24924925 55.28128128 55.31331331
#  55.34534535 55.37737738 55.40940941 55.44144144 55.47347347 55.50550551
#  55.53753754 55.56956957] , y los primeros 50 pdf [3.34575564e-05 3.45455116e-05 3.56665570e-05 3.68216204e-05
#  3.80116528e-05 3.92376295e-05 4.05005498e-05 4.18014383e-05
#  4.31413450e-05 4.45213460e-05 4.59425441e-05 4.74060691e-05
#  4.89130787e-05 5.04647588e-05 5.20623245e-05 5.37070202e-05
#  5.54001204e-05 5.71429306e-05 5.89367876e-05 6.07830601e-05
#  6.26831496e-05 6.46384910e-05 6.66505531e-05 6.87208395e-05
#  7.08508890e-05 7.30422766e-05 7.52966140e-05 7.76155507e-05
#  8.00007740e-05 8.24540104e-05 8.49770260e-05 8.75716277e-05
#  9.02396631e-05 9.29830222e-05 9.58036378e-05 9.87034862e-05
#  1.01684588e-04 1.04749009e-04 1.07898862e-04 1.11136305e-04
#  1.14463545e-04 1.17882838e-04 1.21396487e-04 1.25006849e-04
#  1.28716329e-04 1.32527386e-04 1.36442531e-04 1.40464330e-04
#  1.44595404e-04 1.48838428e-04]

# %%
#Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins= 15, alpha= 0.4, color='b')
plt.title('Distribucion normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
#visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label ='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std,2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt.xlabel('Peso en Kg. de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
#graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )

plt.title('Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()
