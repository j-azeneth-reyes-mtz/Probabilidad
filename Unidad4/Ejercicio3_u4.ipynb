# %% [markdown]
# <a href="https://colab.research.google.com/github/j-azeneth-reyes-mtz/Probabilidad/blob/main/Unidad4/Ejercicio3_u4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística.
# ##Unidad 4.
# ##Ejercicio 3.
# ##Maestro : José Gabriel Rodriguez Rivas.
# ##Alumna : Judith Azeneth Reyes Martínez.

# %%
from scipy.stats import binom

#Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16
X = 16 #Numero de exitos

#Calcular la probabilidad de que nungún paciente sufra la enfermedad
probabilidad_ningun_enfermo = binom.pmf(X, num_pacientes, probabilidad_exito)

print("La probabilidad de que ningún paciente sufra la enefrmedades: ", probabilidad_ningun_enfermo)
# Out:
# La probabilidad de que ningún paciente sufra la enefrmedades:  0.0507282029895386

# %%
from scipy.stats import binom

#Parámetros de la distribución binomial
probabilidad_exito = 0.83
num_pacientes = 16
X = 0

#Calcular la probabilidad de que todos los pacientes sufran la enfermedad
probabilidad_todos_enfermo = binom.pmf(X, num_pacientes, probabilidad_exito)

print("La probabilidad de que todos los pacientes sufran la enefrmedades: ", probabilidad_todos_enfermo)
# Out:
# La probabilidad de que todos los pacientes sufran la enefrmedades:  4.866119187566701e-13
